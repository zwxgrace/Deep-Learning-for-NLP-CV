# %% [markdown]
# <a href="https://colab.research.google.com/github/zwxgrace/Deep-Learning-for-NLP-CV/blob/main/%E2%80%9CC5_X_HEC_BERTopic_ipynb%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transformer-based NLP topic modeling using the Python package BERTopic!!

# %% [markdown]
# **bold text**# Intro
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# BERTopic is a topic modeling python library that uses the combination of transformer embeddings and clustering model algorithms to identify topics in NLP (Natual Language Processing). In this notebook, we will talk about:
# * How transformers, c-TF-IDF, and clustering models are used behind the BERTopic?
# * How to extract and interpret topics from the topic modeling results?
# * How to make predictions using topic modeling?
# * How to save and load a BERTopic topic model?

# %% [markdown]
# # BERTopic Model Algorithms

# %% [markdown]
# In step 0, we will talk about the algorithms behind the BERTopic model.
# * **Documents Embedding**: Firstly, we need to get the embeddings for all the documents. Embeddings are the vector representation of the documents.
#  * BERTopic uses the English version of the `sentence_transformers` by default to get document embeddings.
#  * If there are multiple languages in the document, we can use `BERTopic(language="multilingual")` to support the topic modeling of over 50 languages.
#  * BERTopic also supports the pre-trained models from other python packages such as hugging face and flair.
# * **Dimension Reduction and Documents Clustering**: After the text documents have been transformed into embeddings, the next step is to run a clustering model on the embedded documents. Because the embedding vectors usually have very high dimensions, dimension reduction techniques are used to reduce the dimensionalities.
#  * The default algorithm for dimension reduction is UMAP (Uniform Manifold Approximation & Projection). Compared with other dimension reduction techniques such as PCA (Principle Component Analysis), UMAP maintains the data's local and global structure when reducing the dimensionality, which is important for representing the semantics of the text data. BERTopic provides the option of using other dimensionality reduction techniques by changing the `umap_model` value in the `BERTopic` method.
#  * The default algorithm for clustering is HDBSCAN. HDBSCAN is a density-based clustering model. It identifies the number of clustering automatically, and does not require specifying the number of clusters beforehand like most of the clustering models.
# * **Topic Representation**: After assigning each document in the corpus into a cluster, the next step is to get the topic representation using a class-based TF-IDF called c-TF-IDF. The top words with the highest c-TF-IDF scores are selected to represent each topic.
#  * c-TF-IDF is similar to TF-IDF in that it measures the term importance by term frequencies while taking into account the whole corpus (all the text data for the analysis).
#  * c-TF-IDF is different from TF-IDF in that the term frequency level is different. In the regular TF-IDF, TF measures the term frequency in each document. While in the c-TF-IDF, TF measures the term frequency in each cluster, and each cluster includes many documents.
# * **Maximal Marginal Relevance (MMR)** (optional): After extracting the most important terms describing each cluster, there is an optional step to optimize the terms using Maximal Marginal Relevance (MMR). Maximal Marginal Relevance (MMR) has two benefits:
#  * The first benefit is to increase the coherence among the terms for the same topic and remove irrelevant terms.
#  * The second benefit is to increase the topic representation by removing synonyms and variations of the same words.

# %% [markdown]
# # Install And Import Python Libraries

# %% [markdown]
# In step 1, we will install and import python libraries.
#
# Firstly, let's import `bertopic`.

# %%
# Install bertopic
# !pip install tensorflow==2.18 --quiet
# !pip install bertopic --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.4/615.4 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 34.8 MB/s eta 0:00:00

# %% [markdown]
# Secondly, import necessary packages

# %%
from umap import UMAP
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.vectorizers import ClassTfidfTransformer

import pandas as pd
import numpy as np
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Understand data

# %% [markdown]
# The second step is to download and read the dataset.

# %% [markdown]
# * `drive.mount` is used to mount to the Google drive so the colab notebook can access the data on the Google drive.
# * `os.chdir` is used to change the default directory on Google drive. I set the default directory to the folder where the review dataset is saved.
# * `!pwd` is used to print the current working directory.
#
# Please check out [Google Colab Tutorial for Beginners](https://medium.com/towards-artificial-intelligence/google-colab-tutorial-for-beginners-834595494d44) for details about using Google Colab for data science projects.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Change directory
import os
os.chdir("/content/drive/MyDrive/HEC/reviews_cleaned.parquet")

# Print out the current directory
# !pwd
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-16-ff378c65950e> in <cell line: 0>()
#       5 # Change directory
#       6 import os
# ----> 7 os.chdir("/content/drive/MyDrive/HEC/reviews_cleaned.parquet")
#       8
#       9 # Print out the current directory
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/drive/MyDrive/HEC/reviews_cleaned.parquet'

# %% [markdown]
# Now let's read the data `reviews_cleaned.parquet` into a `pandas` dataframe and see what the dataset looks like.

# %%
# Read in data
reviews_cleaned = pd.read_parquet("/content/drive/MyDrive/HEC/reviews_cleaned.parquet")

# %%
list_total = ['https://fr.trustpilot.com/review/totalenergies.fr', 'https://www.avis-verifies.com/avis-clients/totalenergies.fr', 'https://www.avis-verifies.com/avis-clients/totalenergies.fr?filtre=&p=87',
       'https://www.avis-verifies.com/avis-clients/totalenergies.fr?filtre=&p=478']

# %%
reviews_cleaned
# Out:
#        Unnamed: 0  page                                              titre  \
# 0               0     1                           Aucun soucis particulier
# 1               1     1            Engie facture a ses clients des sommes…
# 2               2     1   Facturation sur consommation d'un autre logement
# 3               3     1                un service client ou il est dur de…
# 4               4     1  Client d'ENGIE depuis longtemps toujours satis...
# ...           ...   ...                                                ...
# 37289       37289   508                                        Avis client
# 37290       37290   508                                        Avis client
# 37291       37291   508                                        Avis client
# 37292       37292   508                                        Avis client
# 37293       37293   508                                        Avis client
#
#                                                 verbatim  \
# 0      Je paie ma facture tous les deux mois en fonct...
# 1      Engie facture a ses clients des sommes exorbit...
# 2      Ils me facturent sur le pdl du logement au des...
# 3      un service client ou il est dur de comprendre ...
# 4      Excellente expérience avec ENGIE et une interl...
# ...                                                  ...
# 37289    Le commercial est très bien Le SAV est à revoir
# 37290    tres professionnel et maintrisant bien le sujet
# 37291  Je le décrirai d'une façon totalement profesio...
# 37292  Un rendez-vous qui s'est très bien déroulé, un...
# 37293  Aucun problème, la conseillère est très profes...
#
#                                  date  note  \
# 0                    Il y a 17 heures     4
# 1                      Il y a un jour     1
# 2                      ll y a 3 jours     1
# 3                      ll y a 3 jours     1
# 4                   Il y a 24 minutes     5
# ...                               ...   ...
# 37289     le 22/02/2022 par Claude P.     5
# 37290      le 22/02/2022 par Jacky P.     4
# 37291      le 22/02/2022 par ANNIC B.     4
# 37292  le 22/02/2022 par Aurélien N.*     5
# 37293    le 22/02/2022 par Jacques A.     5
#
#                                                  reponse  \
# 0                                                   None
# 1      Bonjour Julien Blanco,\n\nPour des raisons de ...
# 2      Bonjour BlooDz,\n\nPour des raisons de confide...
# 3      Bonjour Ricanto77,\nPour des raisons de confid...
# 4                                                   None
# ...                                                  ...
# 37289                                               None
# 37290                                               None
# 37291                                               None
# 37292                                               None
# 37293                                               None
#
#                                          date_experience  \
# 0                 Date de l'expérience: 01 décembre 2022
# 1                 Date de l'expérience: 26 novembre 2022
# 2                 Date de l'expérience: 29 novembre 2022
# 3                 Date de l'expérience: 29 novembre 2022
# 4                 Date de l'expérience: 01 décembre 2022
# ...                                                  ...
# 37289               suite à une expérience du 31/01/2022
# 37290               suite à une expérience du 27/01/2022
# 37291               suite à une expérience du 25/01/2022
# 37292  suite à une expérience du 27/01/2022\n*Informa...
# 37293               suite à une expérience du 27/01/2022
#
#                                              fournisseur         source  \
# 0              https://fr.trustpilot.com/review/engie.fr     trustpilot
# 1              https://fr.trustpilot.com/review/engie.fr     trustpilot
# 2              https://fr.trustpilot.com/review/engie.fr     trustpilot
# 3              https://fr.trustpilot.com/review/engie.fr     trustpilot
# 4              https://fr.trustpilot.com/review/engie.fr     trustpilot
# ...                                                  ...            ...
# 37289  https://www.avis-verifies.com/avis-clients/edf...  avis_verifies
# 37290  https://www.avis-verifies.com/avis-clients/edf...  avis_verifies
# 37291  https://www.avis-verifies.com/avis-clients/edf...  avis_verifies
# 37292  https://www.avis-verifies.com/avis-clients/edf...  avis_verifies
# 37293  https://www.avis-verifies.com/avis-clients/edf...  avis_verifies
#
#                                               clean_verb  \
# 0      je paie ma facture tous les deux mois en fonct...
# 1      engie facture a ses clients des sommes exorbit...
# 2      ils me facturent sur le pdl du logement au des...
# 3      un service client ou il est dur de comprendre ...
# 4      excellente expérience avec engie et une interl...
# ...                                                  ...
# 37289    le commercial est très bien le sav est à revoir
# 37290    tres professionnel et maintrisant bien le sujet
# 37291  je le décrirai d'une façon totalement profesio...
# 37292  un rendez vous qui s'est très bien déroulé un ...
# 37293  aucun problème la conseillère est très profess...
#
#                                                   tokens  \
# 0      [[je, ], [paie, ], [ma, ], [facture, ], [tous,...
# 1      [[engie, ], [facture, ], [a, ], [ses, ], [clie...
# 2      [[ils, ], [me, ], [facturent, ], [sur, ], [le,...
# 3      [[un, ], [service, ], [client, ], [ou, ], [il,...
# 4      [[excellente, ], [expérience, ], [avec, ], [en...
# ...                                                  ...
# 37289  [[le, ], [commercial, ], [est, ], [très, ], [b...
# 37290  [[tres, ], [professionnel, ], [et, ], [maintri...
# 37291  [[je, ], [le, ], [décrirai, ], [d', ], [une, ]...
# 37292  [[un, ], [rendez, ], [vous, ], [qui, ], [s', ]...
# 37293  [[aucun, ], [problème, ], [la, ], [conseillère...
#
#                                               tokens_lem  \
# 0      [[je, ], [pai, ], [ma, ], [factur, ], [tous, ]...
# 1      [[engi, ], [factur, ], [a, ], [se, ], [client,...
# 2      [[il, ], [me, ], [facturent, ], [sur, ], [le, ...
# 3      [[un, ], [servic, ], [client, ], [ou, ], [il, ...
# 4      [[excellent, ], [expérient, ], [avec, ], [engi...
# ...                                                  ...
# 37289  [[le, ], [commercial, ], [est, ], [tres, ], [b...
# 37290  [[tre, ], [professionnel, ], [et, ], [maintris...
# 37291  [[je, ], [le, ], [decr, ], [d', ], [une, ], [f...
# 37292  [[un, ], [rend, ], [vous, ], [qui, ], [s', ], ...
# 37293  [[aucun, ], [problem, ], [la, ], [conseiller, ...
#
#                                         tokens_processed  \
# 0      [paie, facture, mois, fonction, consommation, ...
# 1      [engie, facture, clients, exorbitants, engie, ...
# 2      [facturent, pdl, logement, disant, faute, jama...
# 3      [service, client, dur, comprendre, langue, uti...
# 4      [excellente, expérience, engie, interlocutrice...
# ...                                                  ...
# 37289                          [commercial, sav, revoir]
# 37290                       [professionnel, maintrisant]
# 37291  [décrirai, totalement, profesionnelle, rapport...
# 37292  [rendez, déroulé, nécessaire, savoir, riche, i...
# 37293  [problème, conseillère, professionnelle, entre...
#
#                                     tokens_lem_processed
# 0      [pai, factur, mois, fonction, consomm, exact, ...
# 1      [engi, factur, client, somm, exorbit, engi, fa...
# 2      [facturent, pdl, log, dis, faut, jam, pris, fa...
# 3      [servic, client, dur, comprendr, langu, utilis...
# 4      [excellent, expérient, engi, interlocutric, so...
# ...                                                  ...
# 37289                          [commercial, sav, revoir]
# 37290                     [tre, professionnel, maintris]
# 37291       [decr, total, profesionnel, rapport, demand]
# 37292          [déroul, nécessair, savoir, rich, inform]
# 37293  [conseiller, professionnel, entretien, agréabl...
#
# [37294 rows x 15 columns]

# %%
reviews_cleaned = reviews_cleaned[(reviews_cleaned.note <= 1) & (reviews_cleaned.fournisseur.isin(list_total))]
# note == 1
reviews_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3065 entries, 5002 to 31251
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            3065 non-null   int64
#  1   page                  3065 non-null   int64
#  2   titre                 3065 non-null   object
#  3   verbatim              3065 non-null   object
#  4   date                  3065 non-null   object
#  5   note                  3065 non-null   int64
#  6   reponse               2326 non-null   object
#  7   date_experience       3065 non-null   object
#  8   fournisseur           3065 non-null   object
#  9   source                3065 non-null   object
#  10  clean_verb            3065 non-null   object
#  11  tokens                3065 non-null   object
#  12  tokens_lem            3065 non-null   object
#  13  tokens_processed      3065 non-null   object
#  14  tokens_lem_processed  3065 non-null   object
# dtypes: int64(3), object(12)
# memory usage: 383.1+ KB

# %%
docs = reviews_cleaned['verbatim'].to_list()
# get all comments in a list

# %%
docs
# Out:
# ["Cliente chez total énergie depuis près de deux ans pour ses tarifs qui restent concurrentiels, je vais toutefois changer de fournisseur à cause de leur service client et du manque de transparence dans le suivi des contrats. En effet, je me suis aperçue que Total énergie continuait de me prélever l'abonnement et les frais pour un contrat sans aucune consommation dont j'avais demandé la clôture il y a un an. La réponse du service client a été qu'ils n'avaient pas trace de notre demande de clôture et qu'il n'y aurait aucun remboursement. Ils ont pourtant bien noté l'ouverture d'un autre compte pour la même adresse qui avait été demandé en même temps et qui génère une autre facturation. Dans tous les cas, ils ont un devoir d'information auprès d'un client qui paie un abonnement pour un compte qui affiche zéro consommation depuis plusieurs mois. Bien entendu aucun remboursement ou geste commercial n'a été proposé. Je vais donc saisir le médiateur de l'énergie et changer d'opérateur.",
#  'Nous sommes en litige avec vous des sommes demandées énorme !!!!pas possible !!!plus de 7000 Euro demandé pour une année ????des 300 euro en été ????? pour une maison de 90 mètre carré des demandes de 689 euro de mensualité ???? nous avons demandé qu une personne se déplace pour voir d où vient le problème mais réponse négatif c est une honte nous avons pris RV avec l union fédéral des consommateurs car vous ne voulez pas faire le nécessaire les sommes demandées n existent pas impossible !!!!! Et nous ne comptons pas en rester là !!!!!c est honteux !!!!!',
ent en Backoffice et ne prennent pas le téléphone : je pense tout simplement qu\'ils n\'existent pas. Du coup on est juste confronté à une plateforme marocaine où les gens n\'ont visiblement aucune formation, et ont comme seule réponse à apporter : "je fais remonter l\'information vous serez recontactée". Je n\'ai rien contre eux à titre personnel, mais personne ne leur a appris à suivre un dossier, ils sont juste la pour répondre au téléphone et se prendre les foudres de clients qui comme moi sont au bout du rouleau. Certains cependant ne manque pas d\'être hautain, d\'autres vous propose simplement de vous aider en ne vous faisant payer que la moitié de la note totale (que je conteste) pour éviter de se voir couper le courant. Ils n\'ont même pas la possibilité d\'envoyer les emails. Donc aucun échange suivi possible. Aujourd\'hui on va me couper le courant sans me prévenir (heureusement que je les ai appelée de moi même) et sans avoir résolu le problème. Je suis condamnée à payer une facture concernant le compteur de mon voisin pour pouvoir avoir encore l\'électricité. Après tous les appels, les e-mail, les relances, preuve à l\'appui, expliquant la situation et leur erreur, je m\'aperçois que j\'ai été trop naïve de croire que je pouvais attendre d\'une telle compagnie qu\'elle assume ses responsabilités et résolve les problèmes comme il se doit.\nRien n\'a été fait et aujourd\'hui je vais devoir les traîner en justice pour espérer récupérer mon argent un jour. 😭',
#  "J'étais étudiant à Noisy le grand (93). Des factures qui ne cessent de monter (55e par mois au bout de deux ans pour 18 m² alors que je payais 33 initialement à une époque où j'utilisais bien plus ce studio), un service client avec lequel on ne peut pas communiquer (français très approximatif), et une insatiable envie d'escroquer le client (des amis à moi ont été débités (impossible de faire opposition) alors qu ils se sont retractés dans la durée légale à la vue du service).\nJ'ai résilié le 2 aout 2020, après 1 semaine de bataille pour obtenir ma résiliation (alors qu'il faut 5min pour activer le compte), on m'annonce que j'aurai ma facture de solde au 4 septembre.. (j'ai payé le mois d'aout au plein tarif sur la base de leur estimation en attendant).\nA fuir, privilégiez n'importe quel autre concurrent.\n\nPS : Si vous souhaitez une réponse rapide et complète de leur part, postez un avis négatif sur ce site",
#  'Entreprise à fuir absolument !!!! Harcèlement téléphonique pour régler des factures déjà payer, menaces de coupure alors que tout est payé. Aucune transmission entre les services et services client méprisant et désagréable. À conseiller au masochistes',
#  ...]

# %% [markdown]
# # Embeddings

# %%
# Initiate Embedding model using SentenceTransformer use "paraphrase-multilingual-MiniLM-L12-v2"
embedding_model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")
# choosing embedding methods,
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# BERTopic model by default produces different results each time because of the stochasticity inherited from UMAP.
#
# To get reproducible topics, we need to pass a value to the `random_state` parameter in the `UMAP` method.
# * `n_neighbors=15` means that the local neighborhood size for UMAP is 15. This is the parameter that controls the local versus global structure in data.
#  * A low value forces UMAP to focus more on local structure, and may lose insights into the big picture.
#  * A high value pushes UMAP to look at broader neighborhood, and may lose details on local structure.
#  * The default `n_neighbors` values for UMAP is 15.
# * `n_components=5` indicates that the target dimension from UMAP is 5. This is the dimension of data that will be passed into the clustering model.
# * `min_dist` controls how tightly UMAP is allowed to pack points together. It's the minimum distance between points in the low dimensional space.
#  * Small values of `min_dist` result in clumpier embeddings, which is good for clustering. Since our goal of dimension reduction is to build clustering models, we set `min_dist` to 0.
#  * Large values of `min_dist` prevent UMAP from packing points together and preserves the broad structure of data.
# * `metric='cosine'` indicates that we will use cosine to measure the distance.
# * `random_state` sets a random seed to make the UMAP results reproducible.

# %%
import matplotlib.pyplot as plt

# %%
# Instanciate UMAP
reducer = UMAP(random_state=42, n_neighbors=30, n_components=5, min_dist=0, metric='cosine')

# %% [markdown]
# # Clustering

# %%
# Instanciate HDBSCAN
hscan = HDBSCAN()

# %% [markdown]
# # Vectorizers

# %%
count_vect = CountVectorizer(ngram_range=(1, 3))

# %% [markdown]
# # cTF-IDF
# In BERTopic, in order to get an accurate representation of the topics from our bag-of-words matrix, TF-IDF was adjusted to work on a cluster/categorical/topic level instead of a document level. This adjusted TF-IDF representation is called c-TF-IDF and takes into account what makes the documents in one cluster different from documents in another cluster:

# %%
# Instanciate a ClassTfidf
classTFIDF = ClassTfidfTransformer()

# %% [markdown]
# # Topic Representation
#
# After having generated our topics with c-TF-IDF, we might want to do some fine-tuning based on the semantic relationship between keywords/keyphrases and the set of documents in each topic. Although we can use a centroid-based technique for this, it can be costly and does not take the structure of a cluster into account. Instead, we leverage c-TF-IDF to create a set of representative documents per topic and use those as our updated topic embedding. Then, we calculate the similarity between candidate keywords and the topic embedding using the same embedding model that embedded the documents.

# %%
# Instanciate a keyBERTInspired
keyBERTinsp = KeyBERTInspired()

# %% [markdown]
# # Put All together

# %% [markdown]
# Finally, we pass the processed review documents to the topic model and saved the results for topics and topic probabilities.
#
# The values in topics represents the topic each document is assigned to.
# The values in probabilities represents the probability of a document belongs to each of the topics

# %%
# Instanciate a BERTopic class with all components above and fit to documents
topic_model = BERTopic(embedding_model=embedding_model, umap_model=reducer, hdbscan_model=hscan,
                       vectorizer_model=count_vect, ctfidf_model=classTFIDF,
                       representation_model=keyBERTinsp, language='French')
topics, probabilities = topic_model.fit_transform(docs)

# %% [markdown]
# # Analyse Topics

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   1365   -1_le service_service client_service_fournisseur
# 1       0    105  0_toujours pas électricité_avoir électricité_p...
# 2       1     84                 1_mail_au téléphone_compte_service
# 3       2     83  2_le service clients_du service client_le serv...
# 4       3     81  3_harcèlement téléphonique_du harcèlement_des ...
# ..    ...    ...                                                ...
# 94     93      6  93_mes factures mensuelles_factures mensuelles...
# 95     94      6  94_coupure électricité ai_électricité ai perdu...
# 96     95      6  95_conseillère total energies_energies pour ga...
# 97     96      5  96_injustifié un montant_en service inexplicab...
# 98     97      5  97_et incompréhensibles explications_et incomp...
#
#                                        Representation  \
# 0   [le service, service client, service, fourniss...
# 1   [toujours pas électricité, avoir électricité, ...
# 2   [mail, au téléphone, compte, service, le servi...
# 3   [le service clients, du service client, le ser...
# 4   [harcèlement téléphonique, du harcèlement, des...
# ..                                                ...
# 94  [mes factures mensuelles, factures mensuelles ...
# 95  [coupure électricité ai, électricité ai perdu,...
# 96  [conseillère total energies, energies pour gaz...
# 97  [injustifié un montant, en service inexplicabl...
# 98  [et incompréhensibles explications, et incompr...
#
#                                   Representative_Docs
# 0   [Bonjour, je tiens à partager mon expérience a...
# 1   [J'ai souscrit à un contrat électricité chez d...
# 2   [J'ai souscrit un abonnement le 4 Octobre, via...
# 3   [Des erreurs on été commises par les employés ...
# 4   [Démarchage agressif avec extorsion d'informat...
# ..                                                ...
# 94  [Mes factures mensuelles sont toujours mises e...
# 95  [Je déconseille fortement ce fournisseur !!!\n...
# 96  [Bonjour à tous, je suis actionnaire Total et ...
# 97  [J'ai été victime d'une escroquerie ayant abou...
# 98  [Difficultés de compréhension des interlocuteu...
#
# [99 rows x 5 columns]

# %%
topic_model.get_document_info(docs)
# Out:
#                                                Document  Topic  \
# 0     Cliente chez total énergie depuis près de deux...     -1
# 1     Nous sommes en litige avec vous des sommes dem...     90
# 2     J’ai été démarché par Yamina YAICHE alors que ...     -1
# 3     Services client inexistant . Les personnes qui...     -1
# 4     Des voleurs des voleurs tout simplement mes pa...     35
# ...                                                 ...    ...
# 3060                          Service client médiocre !      2
# 3061  Je me suis finalement rétractée suite à un par...      1
# 3062  Une matinée pour les avoir au téléphone. Quand...     -1
# 3063  Très longue attente pour la souscription plus ...     42
# 3064  4 jours pour avoir quelqu’un au téléphone je t...     42
#
#                                                    Name  \
# 0      -1_le service_service client_service_fournisseur
# 1     90_pour payer autant_payer autant par_ici pour...
# 2      -1_le service_service client_service_fournisseur
# 3      -1_le service_service client_service_fournisseur
# 4     35_gros voleurs_de gros voleurs_des gros voleu...
# ...                                                 ...
# 3060  2_le service clients_du service client_le serv...
# 3061                 1_mail_au téléphone_compte_service
# 3062   -1_le service_service client_service_fournisseur
# 3063  42_téléphone trop long_long to connect_au télé...
# 3064  42_téléphone trop long_long to connect_au télé...
#
#                                          Representation  \
# 0     [le service, service client, service, fourniss...
# 1     [pour payer autant, payer autant par, ici pour...
# 2     [le service, service client, service, fourniss...
# 3     [le service, service client, service, fourniss...
# 4     [gros voleurs, de gros voleurs, des gros voleu...
# ...                                                 ...
# 3060  [le service clients, du service client, le ser...
# 3061  [mail, au téléphone, compte, service, le servi...
# 3062  [le service, service client, service, fourniss...
# 3063  [téléphone trop long, long to connect, au télé...
# 3064  [téléphone trop long, long to connect, au télé...
#
#                                     Representative_Docs  \
# 0     [Bonjour, je tiens à partager mon expérience a...
# 1     [Horrible. Les informations diffèrent d’un con...
# 2     [Bonjour, je tiens à partager mon expérience a...
# 3     [Bonjour, je tiens à partager mon expérience a...
# 4     [Pire fournisseur du monde eni et total\n\nEn ...
# ...                                                 ...
# 3060  [Des erreurs on été commises par les employés ...
# 3061  [J'ai souscrit un abonnement le 4 Octobre, via...
# 3062  [Bonjour, je tiens à partager mon expérience a...
# 3063  [So long to connect. On the phone for an hour....
# 3064  [So long to connect. On the phone for an hour....
#
#                                             Top_n_words  Probability  \
# 0     le service - service client - service - fourni...     0.000000
# 1     pour payer autant - payer autant par - ici pou...     1.000000
# 2     le service - service client - service - fourni...     0.000000
# 3     le service - service client - service - fourni...     0.000000
# 4     gros voleurs - de gros voleurs - des gros vole...     0.793690
# ...                                                 ...          ...
# 3060  le service clients - du service client - le se...     1.000000
# 3061  mail - au téléphone - compte - service - le se...     0.984802
# 3062  le service - service client - service - fourni...     0.000000
# 3063  téléphone trop long - long to connect - au tél...     1.000000
# 3064  téléphone trop long - long to connect - au tél...     0.974288
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 3060                    False
# 3061                    False
# 3062                    False
# 3063                    False
# 3064                    False
#
# [3065 rows x 8 columns]

# %%
# Get the list of topics
topic_model.get_topic(2)
# Out:
# [('le service clients', 0.5256647),
#  ('du service client', 0.5070193),
#  ('le service client', 0.49910468),
#  ('service clients', 0.49698925),
#  ('incompétentes', 0.4823568),
#  ('service client est', 0.480261),
#  ('incompétents', 0.47259435),
#  ('service client', 0.45342886),
#  ('clients et', 0.4284047),
#  ('incompétent', 0.42529547)]

# %% [markdown]
# If more than 4 terms are needed for a topic, we can use `get_topic` and pass in the topic number. For example, `get_topic(0)` gives us the top 10 terms for topic 0 and their relative importance.

# %% [markdown]
# We can visualize the top keywords using a bar chart. `top_n_topics=12` means that we will create bar charts for the top 12 topics. The length of the bar represents the score of the keyword. A longer bar means higher importance for the topic.

# %%
# Visualize top topic keywords
topic_model.visualize_barchart(top_n_topics=12)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f0bd0804-5de4-42ed-a1a8-28426a06522d" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0bd0804-5de4-42ed-a1a8-28426a06522d")) {                    Plotly.newPlot(                        "f0bd0804-5de4-42ed-a1a8-28426a06522d",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.6514325737953186,0.656284749507904,0.6656239628791809,0.670988917350769,0.7045730352401733],"y":["électricité dans  ","sans électricité  ","pas électricité  ","avoir électricité  ","toujours pas électricité  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.32312506437301636,0.3394883871078491,0.3510732650756836,0.39107388257980347,0.45046466588974],"y":["le service  ","service  ","compte  ","au téléphone  ","mail  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.4823567867279053,0.49698925018310547,0.49910467863082886,0.5070192813873291,0.5256646871566772],"y":["incompétentes  ","service clients  ","le service client  ","du service client  ","le service clients  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.43745315074920654,0.4543139636516571,0.4767494201660156,0.49327367544174194,0.541318416595459],"y":["au téléphone  ","appeler  ","des appels  ","du harcèlement  ","harcèlement téléphonique  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.5060432553291321,0.5271146893501282,0.5288760662078857,0.557945966720581,0.5881878733634949],"y":["chèque  ","un remboursement  ","payer  ","remboursement  ","paiement  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.48776352405548096,0.5137172937393188,0.5165243148803711,0.5471696853637695,0.5485501289367676],"y":["payé  ","remboursement  ","factures  ","de payer  ","payer  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.33075419068336487,0.33116263151168823,0.3490312099456787,0.3834243416786194,0.39257460832595825],"y":["du rappeler  ","contrats  ","ai du rappeler  ","contrat  ","le contrat  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.8812525272369385,0.8951113224029541,0.8988245725631714,0.901508629322052,0.9169590473175049],"y":["un  ","oka  ","rar  ","navrant  ","en  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.9698767066001892,0.9699786305427551,0.9757314920425415,0.9868937730789185,0.9974278211593628],"y":["et trop cher  ","trop cher trop  ","beaucoup trop cher  ","bien trop cher  ","trop cher  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.42481550574302673,0.4282785654067993,0.4877442717552185,0.5529241561889648,0.5557459592819214],"y":["électrique  ","énergie  ","direct énergie  ","totalenergies  ","électricité  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.955278217792511,0.9557908773422241,0.9707891941070557,0.9847077131271362,0.9871007204055786],"y":["mauvais mal  ","mauvais horrible  ","mauvais  ","très mauvaise  ","très mauvais  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.38077229261398315,0.39649802446365356,0.40431347489356995,0.4686318635940552,0.4940270185470581],"y":["de tarif  ","fournisseur  ","de fournisseur  ","nouveau fournisseur  ","fournisseur énergie  "],"type":"bar","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5} ...

# %% [markdown]
# Another view for keyword importance is the "Term score decline per topic" chart. It's a line chart with the term rank being the x-axis and the c-TF-IDF score on the y-axis.
#
# There are a total of 31 lines, one line for each topic. Hovering over the line shows the term score information.

# %% [markdown]
# # Topic Similarities

# %% [markdown]
# In step 6, we will analyze the relationship between the topics generated by the topic model.
#
# Intertopic distance map measures the distance between topics. Similar topics are closer to each other, and very different topics are far from each other. From the visualization, we can see that there are five topic groups for all the topics. Topics with similar semantic meanings are in the same topic group.
#
# The size of the circle represents the number of documents in the topics, and larger circles mean that more reviews belong to the topic.

# %%
# Visualize intertopic distance
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="01a85caa-1f4c-4213-9aa8-a02ce7258083" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01a85caa-1f4c-4213-9aa8-a02ce7258083")) {                    Plotly.newPlot(                        "01a85caa-1f4c-4213-9aa8-a02ce7258083",                        [{"customdata":[[0,"toujours pas électricité | avoir électricité | pas électricité | sans électricité | électricité dans",105],[1,"mail | au téléphone | compte | service | le service",84],[2,"le service clients | du service client | le service client | service clients | incompétentes",83],[3,"harcèlement téléphonique | du harcèlement | des appels | appeler | au téléphone",81],[4,"paiement | remboursement | payer | un remboursement | chèque",73],[5,"payer | de payer | factures | remboursement | payé",60],[6,"le contrat | contrat | ai du rappeler | contrats | du rappeler",53],[7,"en | navrant | rar | oka | un",36],[8,"trop cher | bien trop cher | beaucoup trop cher | trop cher trop | et trop cher",36],[9,"électricité | totalenergies | direct énergie | énergie | électrique",35],[10,"très mauvais | très mauvaise | mauvais | mauvais horrible | mauvais mal",34],[11,"fournisseur énergie | nouveau fournisseur | de fournisseur | fournisseur | de tarif",30],[12,"du compteur gaz | compteur gaz | le gaz | de gaz | gaz et",29],[13,"total direct energie | direct energie | électricité | energie | énergie",28],[14,"conseiller très désagréable | très désagréable et | désagréable et menaçant | désagréable | menaçant une honte",26],[15,"mon contrat | lien de contractualisation | un contrat | le contrat | le contrat et",25],[16,"paiement | de paiement | facturation | payé | facture de",25],[17,"électricité | total direct energie | direct energie | direct énergie | total direct",24],[18,"total énergies | électricité | nos consommations | consommation réelle | consommation",22],[19,"possibilité de frais | se faire payer | dingue merci obligation | du compteur consommation | facturation",20],[20,"direct energie est | total direct énergie | total direct energie | direct energie | direct énergie",20],[21,"facture de gaz | changé de fournisseur | le gaz | de gaz | gaz et",20],[22,"prix électricité donc | prix électricité | le prix de | prix du kwh | le prix",19],[23,"et électricité | électricité | total direct énergie | total direct energie | gaz et électricité",18],[24,"informations mensonge galère | des informations fausses | des incompétent | informations fausses informations | informations mensonge",18],[25,"souhaitez renoncer au | septembre rien ne | souhaitez renoncer | renoncer au | siganal que mon",17],[26,"grdf qui | grdf | grdf va | un contrat entretien | contrat entretien de",17],[27,"proposé un contrat | mensualités | mensualité | un contrat | vendu ma maison",17],[28,"de payer électricité | payer électricité consommé | électricité consommé jusqu | des voleurs | voleurs",17],[29,"bosser parce | patron se fait | mon patron se | poches ses salariés | bosser parce qquon",17],[30,"prix sans explication | prix sans augmentation | un prix fixe | de prix hausse | prix fixe",16],[31,"service client | remboursement | du client | service | clients",16],[32,"mon contrat gaz | un contrat gaz | contrat gaz | mon contrat | de mon contrat",16],[33,"contrats chez edf | edf | edf pour | avec edf | chez edf",15],[34,"voleurs | voleurs est | voleurs des | des voleurs | voleurs voleurs",15],[35,"gros voleurs | de gros voleurs | des gros voleurs | des voleurs | voleurs ils",15],[36,"ne reviens jamais | jamais personne ne | jamais personne | ne contacté personne | jamais vers vous",15],[37,"prix du kwh | edf total | prix | le prix | de prix",14],[38,"électricité dans | électricité | plus électricité | devais  ...

# %%
# Visualize connections between topics using hierachical clustering
topic_model.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9ab898aa-99f3-4b6a-94c6-f951ad4e7622" class="plotly-graph-div" style="height:1670px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ab898aa-99f3-4b6a-94c6-f951ad4e7622")) {                    Plotly.newPlot(                        "9ab898aa-99f3-4b6a-94c6-f951ad4e7622",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7802371750883503,0.7802371750883503,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.7802371750883503,0.8148737137398292,0.8148737137398292,0.0],"xaxis":"x","y":[-30.0,-30.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.864392187168111,0.864392187168111,0.8148737137398292],"xaxis":"x","y":[-15.0,-15.0,-37.5,-37.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.864392187168111,0.8854137134576652,0.8854137134576652,0.0],"xaxis":"x","y":[-26.25,-26.25,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9079268551016144,0.9079268551016144,0.8854137134576652],"xaxis":"x","y":[-5.0,-5.0,-40.625,-40.625],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.85485273906686,0.85485273906686,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.85485273906686,0.860482574233263,0.860482574233263,0.0],"xaxis":"x","y":[-70.0,-70.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5872694292909005,0.5872694292909005,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7027040006083191,0.7027040006083191,0.5872694292909005],"xaxis":"x","y":[-105.0,-105.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.7027040006083191,0.7604288721167138,0.7604288721167138,0.0],"xaxis":"x","y":[-112.5,-112.5,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8266609715649311,0.8266609715649311,0.7604288721167138],"xaxis":"x","y":[-95.0,-95.0,-123.75,-123.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.8266609715649311,0.8426849674368108,0.8426849674368108,0.0],"xaxis":"x","y":[-109.375,-109.375,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.860482574233263,0.8800337709892299,0.8800337709892299,0.8426849674368108],"xaxis":"x","y":[-77.5,-77.5,-127.1875,-127.1875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.9079268551016144,0.9565249743609856,0.9565249743609856,0.8800337709892299],"xaxis":"x","y":[-22.8125,-22.8125,-102.34375,-102.34375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8056045722511708,0.8056045722511708,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6197772691673982,0.6197772691673982,0.0],"xaxis":"x","y":[-205.0,-205.0,-215.0,-215.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"}, ...

# %% [markdown]
# Another way to see how the topics are connected is through a hierarchical clustering graph. We can control the number of topics in the graph by the `top_n_topics` parameter.

# %% [markdown]
# Heatmap can also be used to analyze the similarities between topics. The similarity score ranges from 0 to 1. A value close to 1 represents a higher similarity between the two topics, which is represented by darker blue color.

# %% [markdown]
# # Prepare query for GPT3.5

# %% [markdown]
# # Topic Model In-sample Predictions

# %%
topic_model.get_topic(-1)
# Out:
# [('le service', 0.44559225),
#  ('service client', 0.42104477),
#  ('service', 0.4149865),
#  ('fournisseur', 0.4042101),
#  ('demande', 0.38837212),
#  ('contrat', 0.37867734),
#  ('client', 0.37515578),
#  ('électricité', 0.3713158),
#  ('compte', 0.36731124),
#  ('nous', 0.35170263)]

# %%
import math
import pickle

# %%
# Further reduce topics
topic_model.reduce_topics(docs, nr_topics=30)

# %%
def topic_weights(get_topics):
  res = ''
  for word, weight in get_topics:
    if res != '':
      res += ' + '
    add_str = f'{math.ceil(weight*10000)/10000}*"{word}"'
    res += add_str
  return res

# %%
topic_info = topic_model.get_topic_info()

# %%
num_topics = len(topic_info) - 1
num_topics
# Out:
# 29

# %%
topic_str = []
for i in range(num_topics):
  string = topic_weights(topic_model.get_topic(i))
  topic_str.append((i, string))

# %%
topic_str
# Out:
# [(0,
#   '0.5023*"électricité" + 0.4712*"total direct energie" + 0.4684*"direct energie" + 0.4658*"direct énergie" + 0.3931*"energie" + 0.3695*"énergie" + 0.3591*"contrat" + 0.3419*"facture" + 0.3363*"total direct" + 0.3327*"payer"'),
#  (1,
#   '0.5174*"remboursement" + 0.5157*"factures" + 0.5016*"payer" + 0.4835*"une facture" + 0.4642*"facture de" + 0.4543*"facture" + 0.3621*"contrat" + 0.3474*"compte" + 0.3318*"chèque" + 0.2987*"compteur"'),
#  (2,
#   '0.5695*"mon contrat" + 0.4995*"un contrat" + 0.4899*"le contrat" + 0.4705*"contrat" + 0.371*"reçu" + 0.3571*"un conseiller" + 0.3546*"mail" + 0.3507*"service client" + 0.3387*"appel" + 0.3385*"compte"'),
#  (3,
#   '0.5784*"service client incompétent" + 0.5216*"le service client" + 0.4988*"service clients" + 0.4892*"client incompétent" + 0.4844*"payer" + 0.4825*"le client" + 0.4812*"service client" + 0.445*"clients" + 0.4378*"client est" + 0.3937*"un service"'),
#  (4,
#   '0.6213*"harcèlement téléphonique" + 0.5885*"démarchage téléphonique" + 0.5746*"au téléphone" + 0.5525*"le service telephonique" + 0.5448*"téléphonique" + 0.5396*"téléphone et" + 0.5391*"telephone" + 0.5334*"de téléphone" + 0.5309*"des appels" + 0.5235*"service telephonique"'),
#  (5,
#   '0.8822*"nul des" + 0.8821*"navrant" + 0.8767*"voyous nul nul" + 0.8682*"nul des voyous" + 0.8677*"voyous nul" + 0.8611*"oka" + 0.8536*"voleur nul" + 0.8455*"des voyous nul" + 0.8265*"nul parfait" + 0.8162*"nul nul parfait"'),
#  (6,
#   '0.9629*"voleurs" + 0.9604*"des voleurs" + 0.9595*"voleurs des voleurs" + 0.9579*"voleurs des" + 0.9529*"des voleur" + 0.9498*"est des voleurs" + 0.9434*"et des voleurs" + 0.9335*"voleurs vous" + 0.9309*"des voleurs des" + 0.9304*"des voleurs vous"'),
#  (7,
#   '0.9975*"trop cher" + 0.9758*"beaucoup trop cher" + 0.97*"trop cher trop" + 0.9699*"et trop cher" + 0.9663*"plait trop cher" + 0.963*"trop cher prix" + 0.9605*"très cher trop" + 0.953*"prix trop cher" + 0.9467*"trop chère trop" + 0.9386*"cher trop cher"'),
#  (8,
#   '0.7661*"des incompétent très" + 0.7108*"honte incohérences" + 0.7076*"de les embêter" + 0.7066*"honte incohérences entre" + 0.706*"et incompréhensibles fausses" + 0.6863*"les embêter explications" + 0.6776*"incompétent très" + 0.6566*"désagréable et menaçant" + 0.6377*"embêter explications volontairement" + 0.629*"conseiller très désagréable"'),
#  (9,
#   '0.9872*"très mauvais" + 0.9848*"très mauvaise" + 0.9708*"mauvais" + 0.9558*"mauvais horrible" + 0.9553*"mauvais mal" + 0.955*"mauvais très mauvais" + 0.9549*"très mauvais ai" + 0.9484*"mauvaise" + 0.948*"mauvais ai" + 0.9427*"très mauvais horrible"'),
#  (10,
#   '0.768*"prix sans augmentation" + 0.7451*"de prix hausse" + 0.7419*"hausse de prix" + 0.737*"prix hausse de" + 0.7354*"un prix fixe" + 0.7256*"fois plus cher" + 0.7138*"prix fixe pendant" + 0.7039*"plus cher" + 0.7022*"prix sans explication" + 0.6985*"prix hausse"'),
#  (11,
#   '0.6613*"bonjours nous avons" + 0.6442*"nous bon accueil" + 0.6303*"reçu mes réponses" + 0.6278*"rapidement des réponses" + 0.5983*"bonjours nous" + 0.5973*"déjà fait bonjours" + 0.5952*"vous ayant pris" + 0.5897*"bon accueil" + 0.5895*"eu très rapidement" + 0.5796*"bonjours"'),
#  (12,
#   '0.7257*"avoir un contrat" + 0.7057*"crée un contrat" + 0.6969*"un contrat" + 0.6858*"un contrat actif" + 0.6807*"contrat actif une" + 0.6792*"des contrats" + 0.6769*"des contrats qu" + 0.6624*"seulement un contrat" + 0.6588*"contrat en deux" + 0.6321*"un contrat universel"'),
#  (13,
#   '0.575*"énergétique faut pas" + 0.5693*"otage énergétique faut" + 0.5584*"prise otage énergétique" + 0.5522*"du gasoil remettez" + 0.545*"gasoil remettez du" + 0.5333*"énergétique faut" + 0.5266*"de carburant est" + 0.5219*"gasoil remettez" + 0.5089*"totalenergies" + 0.5066*"plus de carburant"'),
#  (14,
#   '0.5497*"septembre rien ne" + 0.4902*"perte avec" + 0.488*"renoncer au" + 0.4815*"siganal que mon" + 0.48*"septembre rien" + 0.4583*"ieme souscription pour" + 0.4536*"se passe reçu" + 0.4509*"cour après" + 0.4426*"en cour après" + 0.4411*"très"'),
#  (15,
#   '0.7445*"ne contacté personne" + 0.7348*"personne ne contacté" + 0.7152*"contacté personne ne" + 0.7137*"personne ne parle" + 0.701*"ne reviens jamais" + 0.6939*"jamais personne" + 0.6937*"jamais personne ne" + 0.693*"car jamais personne" + 0.6885*"ne répondez jamais" + 0.6674*"ne ont jamais"'),
#  (16,
#   '0.9741*"profiteur de crise" + 0.9575*"de crise profiteur" + 0.937*"crise profiteur de" + 0.9258*"crise profiteur" + 0.915*"profiter de crise" + 0.8557*"de crise" + 0.8349*"crise une catastrophe" + 0.8209*"de crise une" + 0.8165*"crise" + 0.8022*"crise une"'),
#  (17,
#   '0.5331*"change votre mensualité" + 0.5137*"mensualité sans vous" + 0.4899*"inefficace démarche de" + 0.4821*"inquiétant service" + 0.4651*"très inquiétant service" + 0.4642*"que votre demande" + 0.462*"ayant duré mois" + 0.4521*"inefficace démarche" + 0.4444*"duré mois et" + 0.444*"fallu refaire toute"'),
#  (18,
#   '0.8214*"téléphone trop long" + 0.7443*"long to connect" + 0.7307*"au téléphone trop" + 0.7053*"téléphone trop" + 0.6798*"très longtemps attente" + 0.6653*"longtemps attente est" + 0.6612*"pris très longtemps" + 0.6576*"passé au téléphone" + 0.6565*"so long to" + 0.6529*"trop longue ai"'),
#  (19,
#   '0.5595*"espace client aucune" + 0.4938*"sur mon compte" + 0.4749*"mon compte" + 0.4637*"mon compte je" + 0.4058*"espace client" + 0.4009*"un compte avec" + 0.3783*"service client" + 0.3746*"mail" + 0.3603*"mot de passe" + 0.3541*"internet car ils"'),
#  (20,
#   '0.8451*"mettre zéro étoile" + 0.8132*"zéro étoile" + 0.7981*"incompétant étoile" + 0.7949*"de sommes astronomiques" + 0.7706*"interminable une étoile" + 0.7637*"fuir incompétant étoile" + 0.757*"sommes astronomiques" + 0.7522*"aucune étoiles" + 0.7509*"incompétant étoile car" + 0.7451*"zéro étoile 00000000000"'),
#  (21,
#   '0.6639*"cher coupure abonnement" + 0.6338*"prix un abonnement" + 0.6244*"téléphone seul abonnement" + 0.6182*"appli mobile souvent" + 0.6039*"dissimulation des prix" + 0.6008*"mobile souvent en" + 0.5965*"disponible plus cher" + 0.5929*"mobile souvent" + 0.5876*"abonnement classique trop" + 0.587*"coupure abonnement"'),
#  (22,
#   '0.6204*"aucunes solutions proposées" + 0.5693*"option sans accord" + 0.5564*"et aucunes solutions" + 0.5522*"aucunes solutions" + 0.5322*"aucune condition générale" + 0.5126*"accord aucune" + 0.5067*"aucune considération" + 0.5021*"aucune considération pour" + 0.5015*"client est minable" + 0.5014*"aucune condition"'),
#  (23,
#   '0.6032*"vous les créditer" + 0.5773*"vous nous envoyez" + 0.5502*"mérite même pas" + 0.543*"étoile parce" + 0.5415*"de 100 promise" + 0.5411*"vous dit" + 0.5369*"vous envoie" + 0.5366*"nous envoyez des" + 0.5237*"une étoile honteux" + 0.5235*"parce qu"'),
#  (24,
#   '0.4639*"appareils électroniques avais" + 0.4432*"20m2 55 euros" + 0.4303*"au téléphone fait" + 0.4252*"est 119 euros" + 0.4167*"électroniques avais" + 0.4154*"119 euros et" + 0.4145*"téléphone fait" + 0.402*"téléphone fait un" + 0.3917*"pourrais changer échéance" + 0.3833*"électroniques avais box"'),
#  (25,
#   '0.665*"fournisseur est mieux" + 0.645*"profits sur notre" + 0.5675*"nous le choix" + 0.5275*"choix aucun fournisseur" + 0.5235*"fournisseur est" + 0.4724*"font que faire" + 0.4683*"que faire des" + 0.4631*"des soirée profits" + 0.4592*"ne font que" + 0.4549*"est mieux qu"'),
#  (26,
#   '0.5437*"pour payer autant" + 0.5255*"payer autant par" + 0.5142*"ici pour payer" + 0.507*"mensuel si cher" + 0.483*"contrat offre verte" + 0.4738*"mois payer" + 0.4627*"payer avance ce" + 0.4599*"mois mois payer" + 0.4583*"si cher parce" + 0.4532*"mois payer avance"'),
#  (27,
#   '0.5559*"souscription par internet" + 0.4816*"un en ligne" + 0.4768*"que je disais" + 0.4672*"comprenait pas la" + 0.459*"en ligne pas" + 0.4566*"je disais et" + 0.4556*"plateforme la personne" + 0.454*"compliqué avoir quelqu" + 0.4516*"faire comprendre je" + 0.4437*"lorsque vous avez"'),
#  (28,
#   '0.5908*"parlait pas correctement" + 0.528*"la langue française" + 0.5014*"français et ne" + 0.4918*"mon interlocutrice ne" + 0.4816*"ne maîtrisait pas" + 0.4714*"langue française" + 0.4689*"pas correctement le" + 0.4646*"expérience mon interlocutrice" + 0.4532*"et ne maîtrisait" + 0.4428*"française ose espérer"')]

# %%
with open('/content/drive/MyDrive/HEC/topic_str.pkl', 'wb') as f:
    pickle.dump(topic_str, f)

# %%
print(type(topic_str))
# Out:
# <class 'list'>

# %%
save_df = reviews_cleaned[['verbatim', 'note']]
save_df.to_parquet('/content/drive/MyDrive/HEC/negative_reviews.parquet')

# %%
save_df
# Out:
#                                                 verbatim  note
# 5002   Cliente chez total énergie depuis près de deux...     1
# 5003   Nous sommes en litige avec vous des sommes dem...     1
# 5004   J’ai été démarché par Yamina YAICHE alors que ...     1
# 5005   Services client inexistant . Les personnes qui...     1
# 5006   Des voleurs des voleurs tout simplement mes pa...     1
# ...                                                  ...   ...
# 31212                          Service client médiocre !     1
# 31217  Je me suis finalement rétractée suite à un par...     1
# 31219  Une matinée pour les avoir au téléphone. Quand...     1
# 31234  Très longue attente pour la souscription plus ...     1
# 31251  4 jours pour avoir quelqu’un au téléphone je t...     1
#
# [3065 rows x 2 columns]

# %% [markdown]
# In step 8, we will talk about how to make in-sample predictions using the topic model.
#
# BERTopic model can output the predicted topic for each review in the dataset.
#
# Using `.topics_`, we save the predicted topics in a list and then save it as a column in the review dataset.

# %%
# Get the topic predictions
topic_preds = topic_model.topics_

# Save the predictions in the dataframe
reviews_cleaned['topics'] = topic_preds

# Take a look at the data
reviews_cleaned['topics']
# Out:
# 5002     145
# 5003     134
# 5004      19
# 5005      24
# 5006      -1
#         ...
# 31250     -1
# 31251     22
# 31261     -1
# 31286     -1
# 31296     -1
# Name: topics, Length: 3844, dtype: int64

# %% [markdown]
# # Topic Model Predictions on New Data

# %% [markdown]
# In this step, we will talk about how to use the BERTopic model to make predictions on new reviews.
#
# Let's say there is a new review "I like the new headphone. Its sound quality is great.", and we would like to automatically predict the topic for this review.
# * Firstly, let's decide the number of topics to include in the prediction.
#  * If we would like to assign only one topic to the document, then the number of topics should be 1.
#  * If we would like to assign multiple topics to the document, then the number of topics should be greater than 1. Here we are getting the top 3 topics that are most relevant to the new review.
# * After that, we pass the new review and the number of topics to the `find_topics` method. This gives us the topic number and the similarity value.
# * Finally, the results are printed. The top 3 similar topics for the new review are topic 1, topic 0, and topic 2. The similarities are 0.43, 0.34, and 0.30.

# %%
# New data for the review
new_review = # Write a fake review

# Find topics of the new review


# Print results

# %% [markdown]
# To verify if the assigned topics are a good fit for the new review, let's get the top keywords for the top 3 topics using the `get_topic` method.

# %%
# Print the top keywords for the top similar topics

# %% [markdown]
# We can see that topic 1 is about headsets and topic 0 is about sound quality. Both topics are a good fit for the new review. Topic 2 is about the earpiece, which is similar to the headset. From this example, we can see that the BERTopic model made good predictions on the new document.

# %% [markdown]
# # Save and Load Topic Models

# %%
# Save the topic model
topic_model.save("amz_review_topic_model")

# Load the topic model
my_model = BERTopic.load("amz_review_topic_model")

# %% [markdown]
# # References

# %% [markdown]
# * [BERTopic GitHub](https://github.com/MaartenGr/BERTopic)
# * [Documentation on BERTopic algorithms](https://maartengr.github.io/BERTopic/algorithm/algorithm.html#visual-overview)
# * [UMAP documentation](https://umap-learn.readthedocs.io/en/latest/parameters.html)
